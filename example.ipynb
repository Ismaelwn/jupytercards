# %% [markdown]
# $~~~~\mbox{ }$

# %% [markdown]
# # Example Usage of Jupyter Cards Feedback,
# ## checkout for "feedback" file to see catched data
# #### display_flashcards(data, Feedback=True) to enable feedback
# #### else display_flashcards(data)

# %%
import os
import json
import sys
import file

from jupytercards import dynamic
from jupytercards import feedback

# %%
with open("def_converted.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
dynamic.display_flashcards(data, Feedback=True)
