# %% [markdown]
# $~~~~\mbox{ }$

# %% [markdown]
# # Example Usage of Jupyter Cards Telemetry,
# ## checkout for "log" file to see catched data

# %%
import os
import json
import sys
import file

from jupytercards import dynamic
from jupytercards import feedback

# %%
with open("def_converted.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
#file.display_card_with_contextual_feedback(data)

# %%
dynamic.display_flashcards(data, Feedback=True)
# Out:
# HBox(children=(Output(layout=Layout(width='75%')), Output(layout=Layout(width='25%'))), layout=Layout(align_it…
# 1
